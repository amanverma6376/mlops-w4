# %%
import os
import mlflow
from google.cloud import storage

# %%
PROJECT_ID = "citric-aleph-461515-j9"
BUCKET_NAME = "mlops-course-citric-aleph-461515-j9-unique"
MLFLOW_TRACKING_URI = f"gs://{BUCKET_NAME}/mlflow-tracking"

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

print(f"MLflow tracking URI: {mlflow.get_tracking_uri()}")
# Out:
# MLflow tracking URI: gs://mlops-course-citric-aleph-461515-j9-unique/mlflow-tracking
